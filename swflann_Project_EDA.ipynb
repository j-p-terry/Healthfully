# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('C:/Users/sflan/Dropbox (Brown)/Healthfully/weather_flu_google_4.csv')

# %%
df.head()
# Out:
#    year  week  total.specimens  percent.positive  cough_medicine  flu_clinic  \
# 0  2010    40             54.0              0.00        55.12500  120.718085
# 1  2010    41             57.0              1.75        55.12500  165.691489
# 2  2010    42             71.0              1.41        81.15625   80.478723
# 3  2010    43             77.0              2.60        53.59375   89.000000
# 4  2010    44             68.0              0.00        49.00000   78.111702
#
#     flu_shot  flu_vaccine        flu  influenza        ...           tamiflu  \
# 0  85.207101    44.615385  17.790698       35.0        ...          3.333333
# 1  47.928994    55.384615  20.755814       29.0        ...          3.333333
# 2  76.331361    32.307692  16.802326       14.0        ...          2.000000
# 3  53.254438    64.615385  14.825581       14.0        ...          2.000000
# 4  37.278107    63.076923  14.825581       28.0        ...          3.333333
#
# ...

# %%
# percent positive over time
plt.scatter(df['week'], df['percent.positive'])
plt.xlabel("week")
plt.ylabel("% positive tests")
plt.title("positive flu tests over time")
# Out:
# Text(0.5,1,'positive flu tests over time')

# %%
# cough medicine searches over time
plt.scatter(df['week'], df['cough_medicine'])
plt.xlabel("week")
plt.ylabel("cough medicine searches (% increase)")
plt.title("cough medicine searches over time")
# Out:
# Text(0.5,1,'cough medicine searches over time')

# %%
# cough medicine searches vs percent positive
plt.scatter(df['cough_medicine'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("cough medicine searches (% increase)")
plt.title("cough medicine searches vs percent positive")
# Out:
# Text(0.5,1,'cough medicine searches vs percent positive')

# %%
# flu clinic searches over time
plt.scatter(df['week'], df['flu_clinic'])
plt.xlabel("week")
plt.ylabel("flu clinic searches (% increase)")
plt.title("flu clinic searches over time")
# Out:
# Text(0.5,1,'flu clinic searches over time')

# %%
# flu clinic searches vs percent positive
plt.scatter(df['flu_clinic'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("flu clinic searches (% increase)")
plt.title("flu clinic searches vs percent positive")
# Out:
# Text(0.5,1,'flu clinic searches vs percent positive')

# %%
# flu vaccine searches over time
plt.scatter(df['week'], df['flu_vaccine'])
plt.xlabel("week")
plt.ylabel("flu vaccine searches (% increase)")
plt.title("flu vaccine searches over time")
# Out:
# Text(0.5,1,'flu vaccine searches over time')

# %%
# flu vaccine searches vs percent positive
plt.scatter(df['flu_vaccine'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("flu vaccine searches (% increase)")
plt.title("flu vaccine searches vs percent positive")
# Out:
# Text(0.5,1,'flu vaccine searches vs percent positive')

# %%
# flu shot searches over time
plt.scatter(df['week'], df['flu_shot'])
plt.xlabel("week")
plt.ylabel("flu shot searches (% increase)")
plt.title("flu shot searches over time")
# Out:
# Text(0.5,1,'flu shot searches over time')

# %%
# flu shot searches vs percent positive
plt.scatter(df['flu_shot'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("flu shot searches (% increase)")
plt.title("flu shot searches vs percent positive")
# Out:
# Text(0.5,1,'flu shot searches vs percent positive')

# %%
# influenza searches over time
plt.scatter(df['week'], df['influenza'])
plt.xlabel("week")
plt.ylabel("influenza searches (% increase)")
plt.title("influenza searches over time")
# Out:
# Text(0.5,1,'influenza searches over time')

# %%
# influenza searches vs percent positive
plt.scatter(df['influenza'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("influenza searches (% increase)")
plt.title("influenza searches vs percent positive")
# Out:
# Text(0.5,1,'influenza searches vs percent positive')

# %%
# oseltamivir searches over time
plt.scatter(df['week'], df['oseltamivir'])
plt.xlabel("week")
plt.ylabel("oseltamivir searches (% increase)")
plt.title("oseltamivir searches over time")
# Out:
# Text(0.5,1,'oseltamivir searches over time')

# %%
# oseltamivir searches vs percent positive
plt.scatter(df['oseltamivir'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("oseltamivir searches (% increase)")
plt.title("oseltamivir searches vs percent positive")
# Out:
# Text(0.5,1,'oseltamivir searches vs percent positive')

# %%
# relenza searches over time
plt.scatter(df['week'], df['relenza'])
plt.xlabel("week")
plt.ylabel("relenza searches (% increase)")
plt.title("relenza searches over time")
# Out:
# Text(0.5,1,'relenza searches over time')

# %%
# relenza searches vs percent positive
plt.scatter(df['relenza'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("relenza searches (% increase)")
plt.title("relenza searches vs percent positive")
# Out:
# Text(0.5,1,'relenza searches vs percent positive')

# %%
# tamiflu searches over time
plt.scatter(df['week'], df['tamiflu'])
plt.xlabel("week")
plt.ylabel("tamiflu searches (% increase)")
plt.title("tamiflu searches over time")
# Out:
# Text(0.5,1,'tamiflu searches over time')

# %%
# tamiflu searches vs percent positive
plt.scatter(df['tamiflu'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("tamiflu searches (% increase)")
plt.title("tamiflu searches vs percent positive")
# Out:
# Text(0.5,1,'tamiflu searches vs percent positive')

# %%
# zanamivir searches over time
plt.scatter(df['week'], df['zanamivir'])
plt.xlabel("week")
plt.ylabel("zanamivir searches (% increase)")
plt.title("zanamivir searches over time")
# Out:
# Text(0.5,1,'zanamivir searches over time')

# %%
# zanamivir searches vs percent positive
plt.scatter(df['zanamivir'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("zanamivir searches (% increase)")
plt.title("zanamivir searches vs percent positive")
# Out:
# Text(0.5,1,'zanamivir searches vs percent positive')

# %%
# flu symptoms searches over time
plt.scatter(df['week'], df['flu_symptoms'])
plt.xlabel("week")
plt.ylabel("flu symptoms searches (% increase)")
plt.title("flu symptoms searches over time")
# Out:
# Text(0.5,1,'flu symptoms searches over time')

# %%
# flu symptoms searches vs percent positive
plt.scatter(df['flu_symptoms'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("flu symptoms searches (% increase)")
plt.title("flu symptoms searches vs percent positive")
# Out:
# Text(0.5,1,'flu symptoms searches vs percent positive')

# %%
# median tmax vs percent positive
plt.scatter(df['median_tmax'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("median tmax")
plt.title("median tmax vs percent positive")
# Out:
# Text(0.5,1,'median tmax vs percent positive')

# %%
# median tmin vs percent positive
plt.scatter(df['median_tmin'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("median tmin")
plt.title("median tmin vs percent positive")
# Out:
# Text(0.5,1,'median tmin vs percent positive')

# %%
# median t vs percent positive
plt.scatter(df['median_t'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("median t")
plt.title("median t vs percent positive")
# Out:
# Text(0.5,1,'median t vs percent positive')

# %%
# total precipitation vs percent positive
plt.scatter(df['total_prcp'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("total precipitation (in)")
plt.title("total precipitation vs percent positive")
# Out:
# Text(0.5,1,'total precipitation vs percent positive')

# %%
# humidity vs percent positive
plt.scatter(df['humidity'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("humidity")
plt.title("humidity vs percent positive")
# Out:
# Text(0.5,1,'humidity vs percent positive')

# %%
# vac num vs percent positive
plt.scatter(df['vac_num'], df['percent.positive'])
plt.ylabel("% positive")
plt.xlabel("vac_num")
plt.title("vac_num vs percent positive")
# Out:
# Text(0.5,1,'vac_num vs percent positive')

# %%
# vac effectiveness vs percent positive
plt.scatter(df['vac_effectiveness'], df['percent.positive'])
plt.xlabel("vac_effectiveness")
plt.ylabel("% positive")
plt.title("vac_effectiveness vs percent positive")
# Out:
# Text(0.5,1,'vac_effectiveness vs percent positive')

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# # Generate a large random dataset
# rs = np.random.RandomState(33)
# d = pd.DataFrame(data=rs.normal(size=(100, 26)),
#                  columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df['cases'] = df['percent.positive'] * df['total.specimens']

# %%
df['cases']
# Out:
# 0          0.00
# 1         99.75
# 2        100.11
# 3        200.20
# 4          0.00
# 5         99.84
# 6        299.88
# 7        199.87
# 8        299.73
# 9       2300.48
# 10      2099.90
# 11      4500.21
# 12     10200.32
# 13     12298.65
# 14     10199.85
# 15     14100.84
# 16      9999.76
# 17     13199.13
# 18     12501.36
# 19     19501.08
# 20     18001.17
# 21     13698.52
# 22     11701.48
# 23     10001.40
# 24      7499.25
# 25      5400.00
# 26      3500.56
# 27      2399.22
# 28      2200.59
# 29       899.36
#          ...
# 388     9298.02
# 389     8303.04
# 390     7699.23
# 391     7699.06
# 392     8300.00
# 393     5698.35
# 394     3498.90
# 395     1300.77
# 396      601.44
# 397      400.40
# 398      498.96
# 399      301.04
# 400       99.06
# 401      100.62
# 402        0.00
# 403      199.76
# 404        0.00
# 405        0.00
# 406        0.00
# 407        0.00
# 408        0.00
# 409        0.00
# 410        0.00
# 411        0.00
# ...

# %%
df2 = pd.read_csv('C:/Users/sflan/Dropbox (Brown)/Healthfully/weather_flu_google_5.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7e45ab7579ac> in <module>()
# ----> 1 df2 = pd.read_csv('C:/Users/sflan/Dropbox (Brown)/Healthfully/weather_flu_google_5.csv')
#
# NameError: name 'pd' is not defined

# %%
df2['cases'] = df2['percent.positive'] * df2['total.specimens']/100

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Compute the correlation matrix
corr = df2.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df3 = df2.dropna()

# %%
# sns.set(style="white")

# Compute the correlation matrix
corr = df3.corr()

# # Generate a mask for the upper triangle
# mask = np.zeros_like(corr, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True

# # Set up the matplotlib figure
# f, ax = plt.subplots(figsize=(11, 9))

# # Generate a custom diverging colormap
# cmap = sns.diverging_palette(220, 10, as_cmap=True)

# # Draw the heatmap with the mask and correct aspect ratio
# sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
#             square=True, linewidths=.5, cbar_kws={"shrink": .5})

sns.heatmap(corr)

# %%
plt.scatter(df3['median_t'], df3['cases'])
plt.plot(np.unique(df3['median_t']), np.poly1d(np.polyfit(df3['median_t'], df3['cases'], 1))(np.unique(df3['median_t'])))
plt.xlabel('median temperature (degF)')
plt.ylabel('cases')
plt.title('Weekly Cases vs. Temperature')
# Out:
# Text(0.5,1,'Weekly Cases vs. Temperature')

# %%
plt.scatter(df3['absolute_humidity'], df3['cases'])
plt.plot(np.unique(df3['median_t']), np.poly1d(np.polyfit(df3['median_t'], df3['cases'], 1))(np.unique(df3['median_t'])))
plt.xlabel('median temperature (degF)')
plt.ylabel('cases')
plt.title('Weekly Cases vs. Temperature')

# %%
plt.plot(df3['week'], df3['cases'])

# %%
df4 = pd.read_csv('C:/Users/sflan/Dropbox (Brown)/Healthfully/Clean Data/weather_flu_google_9.csv')

# %%
df4['cases'] = df4['percent.positive'] * df4['total.specimens']/100
df5 = df4.dropna()

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Compute the correlation matrix
corr = df5.corr(method='spearman')

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr.sort_values(by='cases', axis=0, ascending=True).sort_values(by='cases', axis=1, ascending=False), mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
plt.scatter(df5['median_t'], df5['cases'])
plt.plot(np.unique(df5['median_t']), np.poly1d(np.polyfit(df5['median_t'], df5['cases'], 1))(np.unique(df5['median_t'])))
plt.xlabel('median temperature (degF)')
plt.ylabel('cases')
plt.title('Weekly Cases vs. Temperature')
# Out:
# Text(0.5,1,'Weekly Cases vs. Temperature')

# %%
plt.scatter(df5['absolute_humidity'], df5['cases'])
plt.plot(np.unique(df5['absolute_humidity']), np.poly1d(np.polyfit(df5['absolute_humidity'], df5['cases'], 1))(np.unique(df5['absolute_humidity'])))
plt.xlabel('median humidity(%)')
plt.ylabel('cases')
plt.title('Weekly Cases vs. Absolute Humidity')
# Out:
# Text(0.5,1,'Weekly Cases vs. Absolute Humidity')

# %%
plt.scatter(df5['tamiflu'], df5['cases'])
plt.plot(np.unique(df5['tamiflu']), np.poly1d(np.polyfit(df5['tamiflu'], df5['cases'], 1))(np.unique(df5['tamiflu'])))
plt.xlabel('tamiflu searches (%)')
plt.ylabel('cases')
plt.title('Weekly Cases vs. Tamiflu')
# Out:
# Text(0.5,1,'Weekly Cases vs. Tamiflu')

# %%
plt.scatter(df5['flu_symptoms'], df5['cases'])
plt.plot(np.unique(df5['flu_symptoms']), np.poly1d(np.polyfit(df5['flu_symptoms'], df5['cases'], 1))(np.unique(df5['flu_symptoms'])))
plt.xlabel('flu symptoms searches (%)')
plt.ylabel('cases')
plt.title('Weekly Cases vs. Flu Symptoms')
# Out:
# Text(0.5,1,'Weekly Cases vs. Flu Symptoms')
